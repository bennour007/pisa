# %%
import pandas as pd
import numpy as np
from pystoned import CNLS, CNLSDDF, StoNED
from pystoned.constant import CET_MULT, CET_ADDI, FUN_COST, FUN_PROD, RTS_VRS, RTS_CRS, RED_MOM, OPT_LOCAL, RED_QLE, RED_KDE

# %%
data = pd.read_csv("../../../data_ready/data_ready.csv").replace([np.inf, -np.inf], np.nan).dropna()

# %%
# data

# %%
def normi(x):
    x = (x - min(x))/(max(x)-min(x))
    return(x)

# data[["total_students", "ratio_f2m", "ratio_s2t", "ratio_ft2pt"]].apply(lambda x: normi(x))

# %%
data_cze = data[data["CNT"] == 'CZE']

inputs_cze = data_cze[["total_students", "ratio_f2m", "ratio_s2t", "ratio_ft2pt"]].apply(np.log, axis = 1).values.tolist()
outputs_cze = data_cze[["avg_math", "avg_science", "avg_read"]].apply(np.log, axis = 1)
d_outputs_cze = data_cze[["avg_math", "avg_science", "avg_read"]].values.tolist()
undesirables_cze = data_cze[["dropout_rate"]].values.tolist()
contextuals_cze = data_cze[["bol_competition", "bol_location"]].values.tolist()
data_cze["avg_scores"] = outputs_cze.mean(axis = 1)
z_output_cze = data_cze[["avg_scores"]].apply(np.log, axis = 1).values.tolist()
# Out:
# <ipython-input-28-ab121b5bd934>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cze["avg_scores"] = outputs_cze.mean(axis = 1)

# %%
# np.isinf(data_cze[["avg_scores"]].apply(np.log)).sum()
# Out:
# avg_scores    0
# dtype: int64

# %%
model1_cze = CNLS.CNLS(
    y = z_output_cze, 
    x = inputs_cze, 
    z = contextuals_cze, 
    cet = CET_ADDI, 
    fun = FUN_PROD, 
    rts = RTS_CRS
)

model2_cze = CNLS.CNLS(
    y = z_output_cze, 
    x = inputs_cze, 
    z = contextuals_cze, 
    cet = CET_ADDI, 
    fun = FUN_PROD, 
    rts = RTS_VRS
)

# define the CNLSDDF model with undesirable output
model3_cze = CNLSDDF.CNLSDDF(
    y = d_outputs_cze, 
    x = inputs_cze, 
    b = undesirables_cze, 
    gb = -1.0,
    gy = [1.0, 1.0, 1.0],
    gx = [0, 0, 0, 0],
    fun = FUN_PROD
)

# define the CNLSDDF model with undesirable output
model4_cze = CNLSDDF.CNLSDDF(
    y = d_outputs_cze, 
    x = inputs_cze, 
    gy = [1.0, 1.0, 1.0],
    gx = [0, 0, 0, 0],
    fun = FUN_PROD
)

# %%
model1_cze.optimize(OPT_LOCAL)
model2_cze.optimize(OPT_LOCAL)
model3_cze.optimize(OPT_LOCAL)
model4_cze.optimize(OPT_LOCAL)
# Out:
# Optimizing locally.
# Estimating the additive model locally with mosek solver.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 34969
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1311
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Quadratic to conic reformulation started.
# Quadratic to conic reformulation terminated. Time: 0.02
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 187
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.02
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.21
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 34969
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1311
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 750
# Optimizer  - Cones                  : 2
# Optimizer  - Scalar variables       : 35716             conic                  : 192
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.11              dense det. time        : 0.00
# Factor     - ML order time          : 0.01              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.82e+05          after factor           : 2.82e+05
# Factor     - dense dim.             : 1                 flops                  : 1.43e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.7e+00  1.0e+00  2.0e+00  0.00e+00   5.000000000e-01   0.000000000e+00   1.0e+00  0
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.7283378432e+00    nrm: 1e+00    Viol.  con: 1e-08    var: 2e-09
#   Dual.    obj: 2.7283385109e+00    nrm: 2e+00    Viol.  con: 6e-08    var: 5e-07
# Optimizing locally.
# Estimating the additive model locally with mosek solver.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 34969
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1311
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Quadratic to conic reformulation started.
# Quadratic to conic reformulation terminated. Time: 0.01
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 187
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.01
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.21
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 34969
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1311
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 937
# Optimizer  - Cones                  : 2
# Optimizer  - Scalar variables       : 35716             conic                  : 192
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.11              dense det. time        : 0.00
# Factor     - ML order time          : 0.01              GP order time          : 0.00
# Factor     - nonzeros before factor : 4.40e+05          after factor           : 4.40e+05
# Factor     - dense dim.             : 1                 flops                  : 2.78e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.7e+00  1.0e+00  2.0e+00  0.00e+00   5.000000000e-01   0.000000000e+00   1.0e+00  0.42
# 1   1.6e+00  9.5e-01  1.1e+00  -3.97e-01  2.163381895e+00   6.101045185e-01   9.5e-01  0.59
# 2   1.4e+00  8.1e-01  8.2e-02  6.08e+00   1.360942171e+00   1.106482082e+00   8.1e-01  0.67
# 3   9.2e-01  5.3e-01  2.9e-02  4.68e+00   1.449602371e+00   1.391795720e+00   5.3e-01  0.74
# 4   8.1e-01  4.7e-01  1.8e-02  4.91e+00   1.413983484e+00   1.386392783e+00   4.7e-01  0.81
# 5   5.7e-01  3.3e-01  8.8e-03  3.17e+00   1.410679197e+00   1.399107326e+00   3.3e-01  0.87
# 6   2.5e-01  1.4e-01  2.1e-03  2.32e+00   1.406682526e+00   1.403379859e+00   1.4e-01  0.97
# 7   2.0e-01  1.2e-01  1.5e-03  1.40e+00   1.405633751e+00   1.402959355e+00   1.2e-01  1.03
# 8   5.8e-02  3.3e-02  1.8e-04  1.30e+00   1.401636546e+00   1.400952272e+00   3.3e-02  1.17
# 9   3.3e-02  1.9e-02  7.5e-05  9.07e-01   1.399262720e+00   1.398859131e+00   1.9e-02  1.28
# 10  2.6e-02  1.5e-02  4.9e-05  9.45e-01   1.398330151e+00   1.398017998e+00   1.5e-02  1.35
# 11  1.2e-02  7.2e-03  1.5e-05  9.75e-01   1.396677665e+00   1.396524890e+00   7.2e-03  1.44
# 12  9.5e-03  5.5e-03  9.6e-06  9.96e-01   1.396151664e+00   1.396034804e+00   5.5e-03  1.50
# 13  7.5e-03  4.4e-03  6.7e-06  1.01e+00   1.395796032e+00   1.395703257e+00   4.4e-03  1.57
# 14  3.5e-03  2.0e-03  1.9e-06  1.01e+00   1.394948906e+00   1.394906504e+00   2.0e-03  1.65
# 15  2.8e-03  1.6e-03  1.3e-06  1.02e+00   1.394780532e+00   1.394746503e+00   1.6e-03  1.74
# 16  2.0e-03  1.2e-03  7.9e-07  1.03e+00   1.394585108e+00   1.394560686e+00   1.2e-03  1.84
# 17  1.7e-03  9.9e-04  6.0e-07  1.04e+00   1.394508172e+00   1.394487653e+00   9.9e-04  1.98
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/pystoned/CNLSDDF.py in ?(self, email, solver)
#      76             email (string): The email address for remote optimization. It will optimize locally if OPT_LOCAL is given.
#      77             solver (string): The solver chosen for optimization. It will optimize with default solver if OPT_DEFAULT is given.
#      78         """
#      79         # TODO(error/warning handling): Check problem status after optimization
# ---> 80         self.problem_status, self.optimization_status = tools.optimize_model(
#      81             self.__model__, email, CET_ADDI, solver)
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/pystoned/utils/tools.py in ?(model, email, cet, solver)
#      33                 "Please specify the solver for optimizing multiplicative model locally.")
#      34         solver_instance = SolverFactory(solver)
#      35         print("Estimating the {} locally with {} solver.".format(
#      36             CET_Model_Categories[cet], solver), flush=True)
# ---> 37         return solver_instance.solve(model, tee=True), 1
#      38     else:
#      39         if solver is OPT_DEFAULT and cet is CET_ADDI:
#      40             solver = "mosek"
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/pyomo/solvers/plugins/solvers/direct_solver.py in ?(self, *args, **kwds)
#     218         finally:
#     219             #
#     220             # Reset the options dict
#     221             #
# --> 222             self.options = orig_options
#     223
#     224         return result
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/pyomo/solvers/plugins/solvers/direct_solver.py in ?(self, *args, **kwds)
#      64                 + "supplied."
#      65             ).format(type(self), len(args))
#      66             raise ValueError(msg)
#      67
# ---> 68         self._set_instance(model, kwds)
#      69
#      70         DirectOrPersistentSolver._presolve(self, **kwds)
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/pyomo/solvers/plugins/solvers/mosek_direct.py in ?(self, model, kwds)
#     204         except:
#     205             err_msg = sys.exc_info()[1]
#     206             logger.error("MOSEK task creation failed. " + "Reason: {}".format(err_msg))
#     207             raise
# --> 208         self._add_block(model)
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/pyomo/solvers/plugins/solvers/mosek_direct.py in ?(self, block)
#     571                 if (not con.has_lb()) and (not con.has_ub()):
#     572                     assert not con.equality
#     573                     continue  # non-binding, so skip
#     574                 con_list.append(con)
# --> 575             self._add_constraints(con_list)
#     576
#     577             for con in sub_block.component_data_objects(
#     578                 ctype=pyomo.core.base.sos.SOSConstraint,
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/pyomo/solvers/plugins/solvers/mosek_direct.py in ?(self, con_seq)
#     490             qcsubj = tuple(itertools.chain.from_iterable(q_js))
#     491             qcval = tuple(itertools.chain.from_iterable(q_vals))
#     492             qcsubk = tuple(i for i in sub for j in range(len(q_is[i - con_num])))
#     493             self._solver_model.appendcons(num_lq)
# --> 494             self._solver_model.putarowlist(sub, ptrb, ptre, asubs, avals)
#     495             self._solver_model.putqcon(qcsubk, qcsubi, qcsubj, qcval)
#     496             self._solver_model.putconboundlist(sub, bound_types, lbs, ubs)
#     497             for i, s_n in enumerate(sub_names):
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/mosek/__init__.py in ?(self, *args, **kwds)
#   11363         [ptrb : array(int64)]  Array of pointers to the first element in the rows.
#   11364         [ptre : array(int64)]  Array of pointers to the last element plus one in the rows.
#   11365         [sub : array(int32)]  Indexes of rows or columns that should be replaced.
#   11366       """
# > 11367       return self.__putarowlist64_OOOOO_6(*args,**kwds)
#
# ~/miniconda3/envs/papyr2/lib/python3.9/site-packages/mosek/__init__.py in ?(self, sub, ptrb, ptre, asub, aval)
#   11351             aval_ = _tmparray_aval
#   11352       _res_putarowlist64,_retargs_putarowlist64 = self.__obj.putarowlist64_OOOOO_6(memview_sub,memview_ptrb,memview_ptre,memview_asub,memview_aval)
#   11353       if _res_putarowlist64 != 0:
#   11354         _,_msg_putarowlist64 = self.__getlasterror(_res_putarowlist64)
# > 11355         raise Error(rescode(_res_putarowlist64),_msg_putarowlist64)
#
# Error: rescode.err_invalid_aij(1473): The value of the A matrix element in constraint '' (186) for variable 'x936' (935) is invalid.

# %%
### inefficiency
ineff1_cze = StoNED.StoNED(model1_cze)
ineff2_cze = StoNED.StoNED(model2_cze)
ineff3_cze = StoNED.StoNED(model3_cze)
ineff4_cze = StoNED.StoNED(model4_cze)

# %%
res_cze = {
    "res1_cze" : {
        "alpha" : "None",
        "beta" : model1_cze.get_beta(),
        "delta" : "None",
        "gamma" : "None",
        "lamda" : model1_cze.get_lamda(),
        "residuals" : model1_cze.get_residual(),
        "frontier" : model1_cze.get_frontier(),
        "unconditional_expected_inefficiency" : ineff1_cze.get_unconditional_expected_inefficiency(method = RED_KDE),
        "technical_inefficiency" : ineff1_cze.get_technical_inefficiency(method = RED_QLE)
    },


    "res2_cze" : {
        "alpha" : model2_cze.get_alpha(),
        "beta" : model2_cze.get_beta(),
        "delta" : "None",
        "gamma" : "None",
        "lamda" : model2_cze.get_lamda(),
        "residuals" : model2_cze.get_residual(),
        "frontier" : model2_cze.get_frontier(),
        "unconditional_expected_inefficiency" : ineff2_cze.get_unconditional_expected_inefficiency(method = RED_KDE),
        "technical_inefficiency" : ineff2_cze.get_technical_inefficiency(method = RED_QLE)
    },


    "res3_cze" : {
        "alpha" : model3_cze.get_alpha(),
        "beta" : model3_cze.get_beta(),
        "delta" : model3_cze.get_delta(),
        "gamma" : model3_cze.get_gamma(),
        "lamda" : "None",
        "residuals" : model3_cze.get_residual(),
        "frontier" : "None",
        "unconditional_expected_inefficiency" : ineff3_cze.get_unconditional_expected_inefficiency(method = RED_KDE),
        "technical_inefficiency" : ineff3_cze.get_technical_inefficiency(method = RED_QLE)
    },


    "res4_cze" : {
        "alpha" : "None",
        "beta" : model4_cze.get_beta(),
        "delta" : "None",
        "gamma" : model4_cze.get_gamma(),
        "lamda" : "None",
        "residuals" : model4_cze.get_residual(),
        "frontier" : "None",
        "unconditional_expected_inefficiency" : ineff4_cze.get_unconditional_expected_inefficiency(method = RED_KDE),
        "technical_inefficiency" : ineff4_cze.get_technical_inefficiency(method = RED_QLE)
    }
}

# %%
import pickle
file = 'res_cze'
open_file = open(file, "wb")
pickle.dump(res_cze, open_file)
open_file.close()

file2 = '../results/res_cze'
open_file2 = open(file2, "wb")
pickle.dump(res_cze, open_file2)
open_file.close()

# open_file = open(file, "rb")
# res_cze = pickle.load(open_file)
# open_file.close()
