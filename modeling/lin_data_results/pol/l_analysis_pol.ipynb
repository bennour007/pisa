# %%
import pandas as pd
import numpy as np
from pystoned import CNLS, CNLSDDF, StoNED
from pystoned.constant import CET_MULT, CET_ADDI, FUN_COST, FUN_PROD, RTS_VRS, RTS_CRS, RED_MOM, OPT_LOCAL, RED_QLE, RED_KDE

# %%
data = pd.read_csv("../../data_ready/data_ready.csv").replace([np.inf, -np.inf], np.nan).dropna()

# %%
data_pol = data[data["CNT"] == 'POL']

inputs_pol = data_pol[["total_students", "ratio_f2m", "ratio_s2t", "ratio_pt2ft"]].apply(np.log, axis = 1).values.tolist()
outputs_pol = data_pol[["avg_math", "avg_science", "avg_read"]]
d_outputs_pol = data_pol[["avg_math", "avg_science", "avg_read"]].apply(np.log, axis = 1).values.tolist()
undesirables_pol = data_pol[["dropout_rate"]].values.tolist()
contextuals_pol = data_pol[["bol_competition", "bol_location"]].values.tolist()
data_pol["avg_scores"] = outputs_pol.mean(axis = 1)
z_output_pol = data_pol[["avg_scores"]].apply(np.log, axis = 1).values.tolist()
# Out:
# <ipython-input-3-6e49e350eed3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_pol["avg_scores"] = outputs_pol.mean(axis = 1)

# %%
model1_pol = CNLS.CNLS(
    y = z_output_pol, 
    x = inputs_pol, 
    z = contextuals_pol,
    cet = CET_ADDI, 
    fun = FUN_PROD, 
    rts = RTS_CRS
)

model2_pol = CNLS.CNLS(
    y = z_output_pol, 
    x = inputs_pol, 
    z = contextuals_pol, 
    cet = CET_ADDI, 
    fun = FUN_PROD, 
    rts = RTS_VRS
)

# define the CNLSDDF model with undesirable output
model3_pol = CNLSDDF.CNLSDDF(
    y = d_outputs_pol, 
    x = inputs_pol, 
    b = undesirables_pol, 
    gb = -1.0,
    gy = [1.0, 1.0, 1.0],
    gx = [0, 0, 0, 0],
    fun = FUN_PROD
)

# define the CNLSDDF model with undesirable output
model4_pol = CNLSDDF.CNLSDDF(
    y = d_outputs_pol, 
    x = inputs_pol, 
    gy = [ 1.0, 1.0, 1.0],
    gx = [0, 0, 0, 0],
    fun = FUN_PROD
)

# %%
model1_pol.optimize(OPT_LOCAL)
model2_pol.optimize(OPT_LOCAL)
model3_pol.optimize(OPT_LOCAL)
model4_pol.optimize(OPT_LOCAL)
# Out:
# Optimizing locally.
# Estimating the additive model locally with mosek solver.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 43681
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1465
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Quadratic to conic reformulation started.
# Quadratic to conic reformulation terminated. Time: 0.04
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 209
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.01
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.60
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 43681
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1465
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 838
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 44518             conic                  : 210
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.36              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 3.52e+05          after factor           : 3.52e+05
# Factor     - dense dim.             : 1                 flops                  : 2.00e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   8.8e+01  1.0e+00  2.0e+00  0.00e+00   5.000000000e-01   0.000000000e+00   1.0e+00  1.13
# 1   7.1e+01  8.1e-01  1.8e+00  -9.77e-01  4.612803635e+01   3.903805919e+01   8.1e-01  1.74
# 2   2.2e+01  2.5e-01  8.2e-01  -9.07e-01  1.458075428e+03   1.524213447e+03   2.5e-01  1.87
# 3   3.3e+00  3.8e-02  7.8e-02  -3.10e-01  9.844639219e+03   9.943252723e+03   3.8e-02  2.30
# 4   6.8e-01  7.8e-03  8.3e-03  1.51e+00   1.278655937e+04   1.282136605e+04   7.8e-03  2.68
# 5   1.1e-01  1.3e-03  5.7e-04  1.05e+00   1.323824578e+04   1.324425892e+04   1.3e-03  2.99
# 6   5.9e-02  6.7e-04  2.1e-04  9.35e-01   1.267520746e+04   1.267836362e+04   6.7e-04  3.26
# 7   4.3e-02  4.8e-04  1.4e-04  8.03e-01   1.205435095e+04   1.205690886e+04   4.8e-04  3.38
# 8   2.7e-02  3.0e-04  6.5e-05  9.79e-01   1.191476027e+04   1.191607582e+04   3.0e-04  3.47
# 9   1.8e-02  2.0e-04  3.8e-05  6.34e-01   1.115956005e+04   1.116054475e+04   2.0e-04  3.61
# 10  1.1e-02  1.2e-04  1.7e-05  9.65e-01   1.077668095e+04   1.077724604e+04   1.2e-04  3.76
# 11  7.1e-03  8.0e-05  9.8e-06  7.99e-01   1.020781031e+04   1.020821015e+04   8.0e-05  3.86
# 12  2.7e-03  3.1e-05  2.3e-06  7.38e-01   9.280713021e+03   9.280847615e+03   3.1e-05  4.01
# 13  1.9e-03  2.2e-05  1.4e-06  8.52e-01   9.059941241e+03   9.060042749e+03   2.2e-05  4.15
# 14  1.5e-03  1.8e-05  1.1e-06  7.76e-01   8.936555865e+03   8.936644978e+03   1.8e-05  4.25
# 15  1.1e-03  1.3e-05  7.2e-07  7.00e-01   8.780633795e+03   8.780711801e+03   1.3e-05  4.36
# 16  8.7e-04  1.0e-05  5.4e-07  5.49e-01   8.657880974e+03   8.657954344e+03   1.0e-05  4.45
# 17  5.6e-04  6.4e-06  3.2e-07  4.75e-01   8.470994837e+03   8.471058497e+03   6.4e-06  4.55
# 18  3.4e-04  3.9e-06  1.8e-07  4.13e-01   8.263277683e+03   8.263332306e+03   3.9e-06  4.64
# 44  1.2e-06  1.3e-08  8.3e-11  9.11e-01   7.530636051e+03   7.530637145e+03   1.3e-08  6.37
# 45  8.2e-07  9.4e-09  5.0e-11  9.15e-01   7.527261361e+03   7.527262165e+03   9.4e-09  6.45
# 46  7.8e-07  8.9e-09  4.7e-11  8.97e-01   7.526751736e+03   7.526752518e+03   8.9e-09  6.51
# 47  2.7e-07  3.0e-09  1.0e-11  9.17e-01   7.521365813e+03   7.521366134e+03   3.0e-09  6.65
# 48  2.6e-07  2.9e-09  9.7e-12  8.91e-01   7.521325176e+03   7.521325486e+03   2.9e-09  6.72
# 49  1.5e-07  1.7e-09  4.2e-12  9.33e-01   7.520153753e+03   7.520153932e+03   1.7e-09  6.78
# 50  1.2e-07  1.4e-09  3.2e-12  9.76e-01   7.519896605e+03   7.519896756e+03   1.4e-09  6.84
# 51  7.7e-08  8.5e-10  1.6e-12  9.74e-01   7.519388104e+03   7.519388199e+03   8.5e-10  6.89
# Optimizer terminated. Time: 6.97
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 7.5192768485e+03    nrm: 8e+03    Viol.  con: 9e-11    var: 0e+00
#   Dual.    obj: 7.5194994548e+03    nrm: 5e+03    Viol.  con: 5e-05    var: 6e-03
# Optimizing locally.
# Estimating the additive model locally with mosek solver.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 43681
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1465
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Quadratic to conic reformulation started.
# Quadratic to conic reformulation terminated. Time: 0.02
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 209
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.03
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.37
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 43681
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1465
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 1047
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 44518             conic                  : 210
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.20              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 5.49e+05          after factor           : 5.50e+05
# Factor     - dense dim.             : 1                 flops                  : 3.88e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   8.8e+01  1.0e+00  2.0e+00  0.00e+00   5.000000000e-01   0.000000000e+00   1.0e+00  0.72
# 52  1.2e-07  1.7e-09  3.2e-12  8.52e-01   4.490558235e+03   4.490558308e+03   1.7e-09  8.71
# 53  5.4e-08  1.2e-09  1.9e-12  8.66e-01   4.490417446e+03   4.490417499e+03   1.2e-09  8.80
# 54  3.8e-08  8.7e-10  1.2e-12  9.01e-01   4.490312184e+03   4.490312222e+03   8.7e-10  9.03
# Optimizer terminated. Time: 9.10
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 4.4902315915e+03    nrm: 3e+04    Viol.  con: 1e-10    var: 0e+00
#   Dual.    obj: 4.4903928142e+03    nrm: 4e+03    Viol.  con: 4e-06    var: 4e-03
# Optimizing locally.
# Estimating the additive model locally with mosek solver.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 43890
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 2090
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Quadratic to conic reformulation started.
# Quadratic to conic reformulation terminated. Time: 0.01
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.01
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.07
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 43890
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 2090
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 2090
# Optimizer  - Cones                  : 2
# Optimizer  - Scalar variables       : 45773             conic                  : 629
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.12              dense det. time        : 0.00
# Factor     - ML order time          : 0.06              GP order time          : 0.00
# Factor     - nonzeros before factor : 3.91e+05          after factor           : 3.93e+05
# Factor     - dense dim.             : 2                 flops                  : 8.41e+07
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.0e+00  0.00e+00   5.000000000e-01   0.000000000e+00   1.0e+00  0.25
# 1   9.4e-01  9.4e-01  2.1e+00  -2.86e+00  7.679132715e+00   4.936961462e+00   9.4e-01  0.31
# 2   9.3e-01  9.3e-01  2.2e+00  -3.30e+00  9.357880378e+00   6.511519393e+00   9.3e-01  0.34
# 3   9.1e-01  9.1e-01  2.2e+00  -3.15e+00  1.036872705e+01   7.932555576e+00   9.1e-01  0.38
# 4   8.1e-01  8.1e-01  2.7e+00  -3.16e+00  1.477372405e+01   1.658717499e+01   8.1e-01  0.41
# 5   5.3e-01  5.3e-01  4.5e+00  -3.49e+00  1.722309325e+03   2.652643495e+03   5.3e-01  0.46
# 57  1.3e-08  1.5e-08  3.2e-11  9.91e-01   1.496633745e+03   1.496633823e+03   1.3e-08  3.08
# 58  1.3e-08  1.5e-08  3.2e-11  9.91e-01   1.496633371e+03   1.496633449e+03   1.3e-08  3.18
# 59  1.3e-08  1.5e-08  3.2e-11  9.91e-01   1.496633359e+03   1.496633437e+03   1.3e-08  3.28
# 60  1.3e-08  1.5e-08  3.2e-11  9.91e-01   1.496633354e+03   1.496633431e+03   1.3e-08  3.39
# 61  1.3e-08  1.5e-08  3.2e-11  9.91e-01   1.496633352e+03   1.496633430e+03   1.3e-08  3.51
# 62  1.3e-08  1.5e-08  3.2e-11  9.91e-01   1.496633351e+03   1.496633429e+03   1.3e-08  3.62
# 63  1.3e-08  1.5e-08  3.2e-11  9.91e-01   1.496633351e+03   1.496633429e+03   1.3e-08  3.75
# 64  1.3e-08  1.5e-08  3.2e-11  9.91e-01   1.496633351e+03   1.496633429e+03   1.3e-08  3.87
# Optimizer terminated. Time: 4.02
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.4965858021e+03    nrm: 3e+03    Viol.  con: 1e-07    var: 0e+00
#   Dual.    obj: 1.4966809784e+03    nrm: 3e+03    Viol.  con: 6e-06    var: 1e-02
# Optimizing locally.
# Estimating the additive model locally with mosek solver.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 43890
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1881
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Quadratic to conic reformulation started.
# Quadratic to conic reformulation terminated. Time: 0.01
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 209
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.01
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.18
# GP based matrix reordering started.
# GP based matrix reordering terminated.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : QO (quadratic optimization problem)
#   Constraints            : 43890
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 1881
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 2
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 1672
# Optimizer  - Cones                  : 2
# Optimizer  - Scalar variables       : 45355             conic                  : 420
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.36              dense det. time        : 0.12
# Factor     - ML order time          : 0.02              GP order time          : 0.04
# Factor     - nonzeros before factor : 1.40e+06          after factor           : 1.40e+06
# Factor     - dense dim.             : 3                 flops                  : 1.57e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 51  1.8e-07  1.9e-09  2.1e-12  9.28e-01   1.496464697e+03   1.496464712e+03   1.9e-09  5.51
# 52  4.4e-07  8.7e-10  6.7e-13  9.46e-01   1.496428204e+03   1.496428211e+03   8.7e-10  5.59
# 53  4.3e-08  1.6e-10  5.9e-14  9.76e-01   1.496407822e+03   1.496407823e+03   1.6e-10  5.72
# Optimizer terminated. Time: 5.75
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 1.4964075323e+03    nrm: 5e+03    Viol.  con: 3e-09    var: 0e+00
#   Dual.    obj: 1.4964081127e+03    nrm: 3e+03    Viol.  con: 3e-07    var: 2e-04

# %%
### inefficiency
ineff1_pol = StoNED.StoNED(model1_pol)
ineff2_pol = StoNED.StoNED(model2_pol)
ineff3_pol = StoNED.StoNED(model3_pol)
ineff4_pol = StoNED.StoNED(model4_pol)

# %%
res_pol = {
    "res1_pol" : {
        "alpha" : "None",
        "beta" : model1_pol.get_beta(),
        "delta" : "None",
        "gamma" : "None",
        "lamda" : model1_pol.get_lamda(),
        "residuals" : model1_pol.get_residual(),
        "frontier" : model1_pol.get_frontier(),
        "unconditional_expected_inefficiency" : ineff1_pol.get_unconditional_expected_inefficiency(method = RED_KDE),
        "technical_inefficiency" : ineff1_pol.get_technical_inefficiency(method = RED_QLE)
    },


    "res2_pol" : {
        "alpha" : model2_pol.get_alpha(),
        "beta" : model2_pol.get_beta(),
        "delta" : "None",
        "gamma" : "None",
        "lamda" : model2_pol.get_lamda(),
        "residuals" : model2_pol.get_residual(),
        "frontier" : model2_pol.get_frontier(),
        "unconditional_expected_inefficiency" : ineff2_pol.get_unconditional_expected_inefficiency(method = RED_KDE),
        "technical_inefficiency" : ineff2_pol.get_technical_inefficiency(method = RED_QLE)
    },


    "res3_pol" : {
        "alpha" : model3_pol.get_alpha(),
        "beta" : model3_pol.get_beta(),
        "delta" : model3_pol.get_delta(),
        "gamma" : model3_pol.get_gamma(),
        "lamda" : "None",
        "residuals" : model3_pol.get_residual(),
        "frontier" : "None",
        "unconditional_expected_inefficiency" : ineff3_pol.get_unconditional_expected_inefficiency(method = RED_KDE),
        "technical_inefficiency" : ineff3_pol.get_technical_inefficiency(method = RED_QLE)
    },


    "res4_pol" : {
        "alpha" : "None",
        "beta" : model4_pol.get_beta(),
        "delta" : "None",
        "gamma" : model4_pol.get_gamma(),
        "lamda" : "None",
        "residuals" : model4_pol.get_residual(),
        "frontier" : "None",
        "unconditional_expected_inefficiency" : ineff4_pol.get_unconditional_expected_inefficiency(method = RED_KDE),
        "technical_inefficiency" : ineff4_pol.get_technical_inefficiency(method = RED_QLE)
    }
}

# %%
import pickle
file = 'res_pol'
open_file = open(file, "wb")
pickle.dump(res_pol, open_file)
open_file.close()

# file2 = '../results/res_pol'
# open_file2 = open(file2, "wb")
# pickle.dump(res_pol, open_file2)
# open_file.close()


# open_file = open(file, "rb")
# res_pol = pickle.load(open_file)
# open_file.close()
